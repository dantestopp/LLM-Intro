# %% [markdown]
# ## Connect and compare LLMs
#
# - Connect to the grok API and choose a model
# - Connect to the Gemini API and choose a model
# - Connect to the OpenAI API and choose 4o-mini
#
# ### Create a prompt and inject a little text snippet of your liking
# - The LLM should use the injected information to answer a question.
#
# ### Compare the outputs
# - Use the same method for every model.
# - Do you see differences?
#
# **Tipp:** for prompt injection you can either use string concatenation or the python String formatter.

# %%
from google import genai
import os
from dotenv import load_dotenv
from google.genai import types
from openai import OpenAI
import anthropic

# %%
load_dotenv()
# Access the API key using the variable name defined in the .env file
google_api_key = os.getenv("GOOGLE_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")
deepinfra_api_key = os.getenv("DEEPINFRA_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")

# %% [markdown]
# ## Google
#
# https://ai.google.dev/gemini-api/docs/text-generation?hl=de
# examples: https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb?hl=de#scrollTo=mIC0pLnJdI8m

# %%
client = genai.Client(api_key=google_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="How does AI work?"
)

# %%
print(response.text)
# Out:
# AI, or **Artificial Intelligence**, in its essence, refers to the ability of machines to simulate human intelligence. This means performing tasks that typically require human cognition, such as learning, problem-solving, decision-making, understanding language, and recognizing patterns.
#
# It's not one single technology, but rather a broad field encompassing many different techniques and approaches. However, the most prevalent and impactful forms of AI today, particularly what people mean when they talk about "AI" in the news, often rely heavily on **Machine Learning (ML)** and **Deep Learning (DL)**.
#
# Here's a simplified breakdown of how AI, particularly modern ML-based AI, generally works:
#
# 1.  **Data: The Fuel for AI**
#     *   **What it is:** AI systems learn from vast amounts of data. This data can be anything: text (books, articles, emails), images (photos, videos), audio (speech, music), numbers (sensor readings, financial transactions), etc.
#     *   **Why it's crucial:** Just like a human needs experience to learn, AI needs data. The more diverse and high-quality the data, the better the AI can learn and perform.
#     *   **Example:** To train an AI to recognize cats, you feed it millions of images labeled "cat" and millions more labeled "not a cat."
#
# 2.  **Algorithms & Models: The Brain of AI**
#     *   **What they are:** Algorithms are sets of rules or instructions that the computer follows. In AI, these algorithms are used to build "models." A model is essentially the AI's learned representation of patterns in the data.
#     *   **How they work:** The algorithm processes the input data to identify patterns, relationships, and features within it. It's like a recipe for learning.
#     *   **Example:** A machine learning algorithm might look for specific shapes, colors, or textures in images to determine if they belong to a cat.
#
# 3.  **Training: The Learning Process**
#     *   **Input:** The AI model is fed the data (e.g., cat images with labels).
#     *   **Prediction:** The model makes a guess based on what it currently "knows." Initially, its guesses are often wrong.
#     *   **Correction/Feedback:** The model's prediction is compared to the correct answer (the label). Any difference is an "error."
#     *   **Adjustment:** The algorithm then adjusts the model's internal parameters (think of these as knobs or weights) in a way that reduces the error for that particular piece of data. This process is repeated thousands or millions of times.
#     *   **Optimization:** Over countless iterations, the model learns to make increasingly accurate predictions by minimizing its errors across the entire dataset. It essentially fine-tunes itself.
#     *   **Goal:** To build a model that can generalize well, meaning it can make accurate predictions on *new, unseen data* that it wasn't trained on.
#
# 4.  **Inference/Prediction: Applying What Was Learned**
#     *   Once the model is trained, it's ready to be used.
#     *   **New Input:** You provide the trained model with new, unseen data (e.g., a new image you've taken).
#     *   **Output:** The model uses its learned patterns and relationships to make a prediction, classification, or generate a response.
#     *   **Example:** You show the trained AI a new picture, and it outputs "cat" with a high probability.
#
# ---
#
# ### Key Branches of AI and How They Work
#
# *   **Machine Learning (ML):** This is the foundation for most modern AI. Instead of being explicitly programmed for every scenario, ML algorithms enable systems to learn from data and improve over time without explicit programming.
#     *   **Supervised Learning:** Learning from labeled examples (e.g., images of "spam" vs. "not spam" emails).
#     *   **Unsupervised Learning:** Finding patterns or structures in unlabeled data (e.g., grouping customers with similar buying habits).
#     *   **Reinforcement Learning:** Learning through trial and error, getting rewards for desired actions and penalties for undesirable ones (e.g., teaching an AI to play a game).
#
# *   **Deep Learning (DL):** A subset of Machine Learning that uses artificial **neural networks** with multiple layers (hence "deep"). These networks are loosely inspired by the structure and function of the human brain.
#     *   **How it works:** Each "neuron" in a layer takes input, performs a calculation, and passes the result to the next layer. Deeper layers learn more complex and abstract features. This hierarchical learning is why deep learning excels at tasks like image recognition, speech processing, and natural language understanding.
#
# *   **Natural Language Processing (NLP):** Enables computers to understand, interpret, and generate human language.
#     *   **How it works:** Uses ML and DL techniques to break down language into its components (words, sentences, grammar, meaning) and learn relationships. Examples: translation (Google Translate), chatbots, sentiment analysis.
#
# *   **Computer Vision (CV):** Enables computers to "see" and interpret visual information from images and videos.
#     *   **How it works:** Uses deep learning (especially Convolutional Neural Networks) to identify objects, faces, scenes, and even emotions within visual data. Examples: facial recognition, self-driving cars, medical image analysis.
#
# ---
#
# ### In Summary:
#
# Modern AI primarily works by **learning from data**. Algorithms analyze vast datasets to identify patterns and relationships, building a "model" that can then apply this learned knowledge to new, unseen information to make predictions, solve problems, or generate creative content. It's a continuous process of data input, algorithmic processing, learning through feedback, and applying that learned intelligence.

# %% [markdown]
# # Openai
# https://platform.openai.com/docs/guides/text

# %%
from openai import OpenAI
client = OpenAI()


response = client.responses.create(
    model="gpt-5-nano",
    input="How does AI work?"
)

print(response.output_text)
# Out:
# At a high level, AI refers to computer systems that can perform tasks that typically require human intelligence, such as recognizing images, understanding language, or making decisions.
#
# Key ideas and how it works
# - Data: AI learns from data. This can be labeled (supervised learning), unlabeled (unsupervised learning), or through interaction (reinforcement learning).
# - Model: A mathematical function (or network of functions) that maps inputs to outputs. In modern AI, many systems use neural networks, especially deep neural networks with many layers.
# - Training: The model adjusts its internal parameters to minimize a loss function, which measures how far its predictions are from the true answers. This adjustment is done via optimization algorithms (like gradient descent) that use examples from the data.
# - Inference: Once trained, the model can make predictions on new, unseen data.
# - Evaluation: We test the model with separate data to see how well it performs, using metrics appropriate to the task (accuracy, RMSE, BLEU score, etc.).
# - Deployment and monitoring: The model is put into production, where it processes real inputs, and its performance is continuously monitored and updated as needed.
#
# Common approaches
# - Machine learning (ML): The broad idea of learning from data.
# - Deep learning (DL): A subset of ML using large neural networks, excellent for image, audio, text, and other complex data.
# - Supervised learning: Learn from labeled examples (e.g., image of a dog labeled “dog”).
# - Unsupervised learning: Find structure in unlabeled data (e.g., clustering customers by behavior).
# - Reinforcement learning: An agent learns to act in an environment by receiving feedback (rewards/punishments) to maximize cumulative reward.
#
# A simple workflow (supervised learning example)
# 1) Problem definition: E.g., predict house prices from features like size, location, age.
# 2) Data collection and preprocessing: Gather data, clean it, handle missing values, scale features.
# 3) Model selection: Choose a model type (linear model, decision trees, neural network).
# 4) Training: Feed the model many labeled examples and adjust parameters to minimize prediction error.
# 5) Evaluation: Test on unseen data to estimate real-world performance.
# 6) Deployment: Use the trained model to make predictions on new houses; monitor and update as needed.
#
# Why data quality matters
# - More important than fancy algorithms: the quality, representativeness, and labeling of the data determine how well an AI system works.
# - Bias and fairness: If the data reflect historical biases, the model may adopt them; ongoing checks are important.
#
# Limitations and caveats
# - AI is most powerful for narrow tasks it’s trained on; it’s not general intelligence.
# - It can struggle with out-of-distribution data, rare events, or tasks requiring common sense.
# - Interpretability and transparency can be challenging for complex models.
# - Privacy, security (e.g., adversarial inputs), and environmental cost are practical concerns.
#
# Real-world examples
# - Image and speech recognition (phones, cameras).
# - Language understanding and chatbots.
# - Recommendation systems (movies, products).
# - Medical diagnosis aids, fraud detection, autonomous robots, and more.
#
# If you tell me your interests or a specific task you’re curious about (e.g., how a spam filter works, how image recognition works, or how a movie recommender is built), I can tailor the explanation or walk you through a concrete example.

# %% [markdown]
# # Deepinfra
# https://deepinfra.com/docs/openai_api
#
# goal: meta-llama/Llama-3.3-70B-Instruct-Turbo

# %%
openai = OpenAI(
    api_key=deepinfra_api_key,
    base_url="https://api.deepinfra.com/v1/openai",
)


chat_completion = openai.chat.completions.create(
    model="meta-llama/Llama-3.3-70B-Instruct-Turbo",
    messages=[{"role": "user", "content": "How does AI work?"}],
    stream=False,
)

print(chat_completion.choices[0].message.content)
# Out:
# Hello! It's nice to meet you. Is there something I can help you with or would you like to chat?

# %% [markdown]
# ## Deepinfra
# https://deepinfra.com/docs/openai_api
#
# goals:
# - llama-3.3-X
# - gemma x x x
# - Qwen x x x
# - deepseek x x x

# %% [markdown]
# ## Anthropic
#
# https://docs.claude.com/en/docs/get-started#python

# %%
client = anthropic.Anthropic()

message = client.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "How does AI work?"
        }
    ]
)
print(message.content)
# Out:
# [TextBlock(citations=None, text='# How AI Works\n\nAI works by using computer systems to perform tasks that typically require human intelligence. Here\'s a breakdown:\n\n## Core Approach\n\n**Pattern Recognition**: AI systems learn to recognize patterns in data, similar to how humans learn from experience. Instead of following rigid programmed rules, they identify relationships and make predictions.\n\n## Key Methods\n\n**Machine Learning**: Systems improve automatically through exposure to data\n- Feed the system lots of examples\n- It finds patterns and creates a model\n- Uses that model to make predictions on new data\n\n**Neural Networks**: Inspired by brain structure\n- Layers of interconnected "nodes" process information\n- Each layer extracts increasingly complex features\n- Deep learning uses many layers for sophisticated tasks\n\n## Training Process\n\n1. **Input data** (images, text, numbers)\n2. **Processing** through algorithms\n3. **Output** a prediction or decision\n4. **Feedback** on accuracy\n5. **Adjustment** of internal parameters to improve\n\n## Example\nFor image recognition:\n- Show AI thousands of cat photos labeled "cat"\n- It learns what features cats share (ears, whiskers, fur patterns)\n- When shown a new image, it recognizes those patterns and identifies cats\n\nThe "intelligence" comes from finding statistical patterns in vast amounts of data, not from understanding in the human sense.', type='text')]
